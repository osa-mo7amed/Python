# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('employees.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'First Name', 'Gender', 'Start Date', 'Last Login Time',
#        'Salary', 'Bonus %', 'Senior Management', 'Department'],
#       dtype='object')

# %%
print(pd.options.display.max_rows)
pd.options.display.max_rows = 60
df
# Out:
# 9999
#       Unnamed: 0 First Name  Gender Start Date Last Login Time  Salary  \
# 0              0    Douglas    Male   8/6/1993        12:42 PM   97308
# 1              1     Thomas    Male  3/31/1996         6:53 AM   61933
# 2              2      Maria  Female  4/23/1993        11:17 AM  130590
# 3              3      Jerry    Male   3/4/2005         1:00 PM  138705
# 4              4      Larry    Male  1/24/1998         4:47 PM  101004
# ...          ...        ...     ...        ...             ...     ...
# 996          996    Phillip    Male  1/31/1984         6:30 AM   42392
# 997          997    Russell    Male  5/20/2013        12:39 PM   96914
# 998          998      Larry    Male  4/20/2013         4:45 PM   60500
# 999          999     Albert    Male  5/15/2012         6:24 PM  129949
# 1000        1000      Osama    Male   5/7/1980         8:42 PM  149620
#
#       Bonus % Senior Management            Department
# 0       6.945              True             Marketing
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       Unnamed: 0 First Name  Gender Start Date Last Login Time  Salary  \
# 0              0    Douglas    Male   8/6/1993        12:42 PM   97308
# 2              2      Maria  Female  4/23/1993        11:17 AM  130590
# 3              3      Jerry    Male   3/4/2005         1:00 PM  138705
# 4              4      Larry    Male  1/24/1998         4:47 PM  101004
# 5              5     Dennis    Male  4/18/1987         1:35 AM  115163
# ...          ...        ...     ...        ...             ...     ...
# 996          996    Phillip    Male  1/31/1984         6:30 AM   42392
# 997          997    Russell    Male  5/20/2013        12:39 PM   96914
# 998          998      Larry    Male  4/20/2013         4:45 PM   60500
# 999          999     Albert    Male  5/15/2012         6:24 PM  129949
# 1000        1000      Osama    Male   5/7/1980         8:42 PM  149620
#
#       Bonus % Senior Management            Department
# 0       6.945              True             Marketing
# ...

# %%
df[["First Name", "Gender", "Salary"]].head(10)
# Out:
#   First Name  Gender  Salary
# 0    Douglas    Male   97308
# 1     Thomas    Male   61933
# 2      Maria  Female  130590
# 3      Jerry    Male  138705
# 4      Larry    Male  101004
# 5     Dennis    Male  115163
# 6       Ruby  Female   65476
# 7        NaN  Female   45906
# 8     Angela  Female   95570
# 9    Frances  Female  139852

# %%
df.iloc[10]["Bonus %"]
# Out:
# np.float64(15.132)

# %%
df.iloc[0:10, 0:3]
# Out:
#   First Name  Gender  Start Date
# 0    Douglas    Male    8/6/1993
# 1     Thomas    Male   3/31/1996
# 2      Maria  Female   4/23/1993
# 3      Jerry    Male    3/4/2005
# 4      Larry    Male   1/24/1998
# 5     Dennis    Male   4/18/1987
# 6       Ruby  Female   8/17/1987
# 7        NaN  Female   7/20/2015
# 8     Angela  Female  11/22/2005
# 9    Frances  Female    8/8/2002

# %%
df[(df["Salary"] > 145000) & (df["Gender"] == "Female")]
# Out:
#      First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
#
# 948      Ashley  Female  3/31/2006         1:24 PM  142410  11.048
# 1000      Osama    Male   5/7/1980         8:42 PM  149620  15.842
#
#      Senior Management   Department
# 143               True  Engineering
# 171               True  Engineering
# 175               True  Engineering
# 447               True  Engineering
# 541               True  Engineering
# ...

# %%
df.loc[df["First Name"] == "Brianne"]
# Out:
#     First Name Gender  Start Date Last Login Time  Salary Bonus %  \
# 688    Brianne   Male  2020-01-01        10:05 AM  142392  13.215
#
#     Senior Management       Department
# 688              True  Client Services

# %%
df.loc[df["First Name"] == "Brianne", "Last Login Time"] = "10:05 AM"

# %%
new_row = pd.DataFrame([{"First Name": "Osama", "Gender": "Male", "Start Date": "5/7/1980", "Last Login Time" : "8:42 PM", "Salary": 149620, "Bonus %" : 15.842, "Senior Management": True, "Department" : "Engineering"}])
df = pd.concat([df, new_row], ignore_index=True)
df.tail(3)

# %%
df.loc[df["First Name"] == "Osama"]
# Out:
#      First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 1000      Osama   Male   5/7/1980         8:42 PM  149620   15.842
#
#      Senior Management   Department
# 1000              True  Engineering

# %%
df.drop(df.tail(1).index, inplace=True)

# %%
df.loc[df["First Name"] == "Osama", "Department"] = "Engineering"

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.dropna() 
# There aslo exists df.fillna() to fill missing values
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2         Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5        Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ...         ...     ...        ...             ...     ...      ...
# 996     Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997     Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998       Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999      Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1000      Osama    Male   5/7/1980         8:42 PM  149620   15.842
#
#      Senior Management            Department
# 0                 True             Marketing
# 2                False               Finance
# ...

# %%
df.rename(columns={"Team":"Department"}, inplace=True)

# %%
df["Department"].value_counts()
# Out:
# Department
# Client Services         107
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              93
# Human Resources          91
# Distribution             90
# Legal                    87
# Name: count, dtype: int64

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Business Development    91866.316832
# Client Services         88730.663551
# Distribution            88500.466667
# Engineering             94864.365591
# Finance                 92219.480392
# Human Resources         90944.527473
# Legal                   89250.770115
# Marketing               90435.591837
# Product                 88665.505263
# Sales                   92173.436170
# Name: Salary, dtype: float64

# %%
df["Salary"] = pd.to_numeric(df["Salary"]) # Convert Salary column to numeric type
df.groupby("Department")["Salary"].sum()
# Out:
# Department
# Business Development    9278498
# Client Services         9494181
# Distribution            7965042
# Engineering             8822386
# Finance                 9406387
# Human Resources         8275952
# Legal                   7764817
# Marketing               8862688
# Product                 8423223
# Sales                   8664303
# Name: Salary, dtype: int64

# %%
Top = df.sort_values(by="Salary", ascending=False)
Top.head(10)
# Out:
#      First Name  Gender Start Date Last Login Time  Salary Bonus %  \
# 644   Katherine  Female  8/13/1996        12:21 AM  149908  18.912
# 429        Rose  Female  5/28/2015         8:40 AM  149903    5.63
# 828     Cynthia  Female  7/12/2006         8:55 AM  149684   7.864
# 186         NaN  Female  2/23/2005         9:50 PM  149654   1.825
# 1000      Osama    Male   5/7/1980         8:42 PM  149620  15.842
# 160       Kathy  Female  3/18/2000         7:26 PM  149563  16.991
# 740     Russell     NaN   5/9/2009        11:59 AM  149456   3.533
# 793      Andrea  Female  7/22/1999         9:25 AM  149105  13.707
# 981       James    Male  1/15/1993         5:19 PM  148985   19.28
# 800    Clarence    Male   8/5/1989         6:11 PM  148941  11.517
#
#      Senior Management       Department
# 644              False          Finance
# 429              False  Human Resources
# 828              False          Product
# 186                NaN            Sales
# ...

# %%
df.dropna()
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2         Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5        Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ...         ...     ...        ...             ...     ...      ...
# 996     Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997     Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998       Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999      Albert    Male  5/15/2012         6:24 PM  129949   10.169
# 1000      Osama    Male   5/7/1980         8:42 PM  149620   15.842
#
#      Senior Management            Department
# 0                 True             Marketing
# 2                False               Finance
# ...

# %%
df.to_csv('employees.csv', index=True)

# %%
x = df["Salary"].mean()
print(f"The average salary is {x}")
x = df["Salary"].median()
print(f"The median salary is {x}")
x = df["Salary"].mode()[0]
print(f"The mode salary is {x}")
x = df["Salary"].std()
print(f"The standard deviation of salary is {x}")
# Out:
# The average salary is 90573.95163398693
# The median salary is 90429.0
# The mode salary is 145988
# The standard deviation of salary is 32965.97885618764

# %%
d = df.duplicated()
if d.any():
    print("There are duplicate rows in the DataFrame")

# %%
df["Bonus %"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"], format="%m/%d/%Y")

# %%
d = df.duplicated()
if d.any():
    print("There are duplicate rows in the DataFrame")

# %%
w = df.isna()
if w.any().any(): # 2 calls to any() to check entire DataFrame
    print("There are missing values in the DataFrame")

# %%
u = df["Department"].unique()
print(f"The unique departments are: {u}")
# Out:
# The unique departments are: ['Marketing' 'Finance' 'Client Services' 'Legal' 'Product' 'Engineering'
#  'Business Development' 'Human Resources' 'Sales' 'Distribution']
